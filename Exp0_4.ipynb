# %% [markdown]
# <a href="https://colab.research.google.com/github/SaeedAkhtar1/BE-Machine-Learning-Lab/blob/main/Exp0_4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Implement Gradient Descent Algorithm to find the local minima of a function.
# For example, find the local minima of the function y=(x+3)² starting from the point x=2.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define the function y = (x + 3)^2
def function(x):
    return (x + 3)**2

# %%
# Define the derivative of the function y' = 2 * (x + 3)
def gradient(x):
    return 2 * (x + 3)

# %%
# Gradient Descent Algorithm
def gradient_descent(starting_x, learning_rate, iterations):
    x = starting_x
    x_values = [x]
    y_values = [function(x)]

    for i in range(iterations):
        grad = gradient(x)
        x = x - learning_rate * grad
        x_values.append(x)
        y_values.append(function(x))
        print(f"Iteration {i+1}: x = {x}, y = {function(x)}")

    return x, function(x), x_values, y_values

# %%
# Parameters
starting_x = 2                # Starting point
learning_rate = 0.1           # Learning rate
iterations = 30               # Number of iterations

# %%
# Run Gradient Descent
min_x, min_y, x_vals, y_vals = gradient_descent(starting_x, learning_rate, iterations)

print(f"\nLocal minima occurs at x = {min_x}, y = {min_y}")
# Out:
# Iteration 1: x = 1.0, y = 16.0
# Iteration 2: x = 0.19999999999999996, y = 10.240000000000002
# Iteration 3: x = -0.44000000000000017, y = 6.553599999999998
# Iteration 4: x = -0.9520000000000001, y = 4.194304
# Iteration 5: x = -1.3616000000000001, y = 2.6843545599999996
# Iteration 6: x = -1.6892800000000001, y = 1.7179869183999996
# Iteration 7: x = -1.951424, y = 1.099511627776
# Iteration 8: x = -2.1611392, y = 0.7036874417766399
# Iteration 9: x = -2.32891136, y = 0.4503599627370493
# Iteration 10: x = -2.463129088, y = 0.28823037615171165
# Iteration 11: x = -2.5705032704, y = 0.1844674407370954
# Iteration 12: x = -2.6564026163200003, y = 0.11805916207174093
# Iteration 13: x = -2.725122093056, y = 0.07555786372591429
# Iteration 14: x = -2.7800976744448, y = 0.04835703278458515
# Iteration 15: x = -2.82407813955584, y = 0.030948500982134555
# Iteration 16: x = -2.8592625116446717, y = 0.019807040628566166
# Iteration 17: x = -2.8874100093157375, y = 0.012676506002282305
# ...

# %%
# Plotting the function and the gradient descent path
x_range = np.linspace(-10, 10, 100)
y_range = function(x_range)

plt.figure(figsize=(10, 6))
plt.plot(x_range, y_range, label='y = (x + 3)^2')
plt.scatter(x_vals, y_vals, color='red', label='Gradient Descent Path')
plt.plot(x_vals, y_vals, color='red', linestyle='--')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Gradient Descent to Find Local Minima')
plt.legend()
plt.grid(True)
plt.show()
